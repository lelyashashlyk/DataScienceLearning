# %% [markdown]
# <a href="https://colab.research.google.com/github/lelyashashlyk/DataScienceLearning/blob/main/numpy/np_lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # Task_1
#
# Даны массивы $x$ и $y$. Для каждой пары элементов массивов выполните вычисление по формуле:
#
# $$z = 2x + 3y - xy$$

# %%
x = np.array([-3, -3, 12,  7,  2,  5, -5, -1,  3, 12,  3, -4,  9, 14, -1,  1,  4,
       13,  9,  5])
y = np.array([13,  0,  9, -1, 12,  4,  1,  1,  0, 13,  8, 14, -3, -5,  2,  8, -3,
        2, 10, -3])

# %%
2*x +3*y - x*y
# Out:
# array([ 72,  -6, -57,  18,  16,   2,  -2,   2,   6, -93,   6,  90,  36,
#         83,   6,  18,  11,   6, -42,  16])

# %% [markdown]
# # Task_2
#
# Даны две матрицы $A$ и $B$. Выполните рассчет результирующей матрицы по формуле:
#
# $$C = 2A - 3B$$

# %%
a = np.array([[  3,   5,  -5,  -6,  -9,   2,  -2],
              [-10,  -3,  -5,   0,   6,   9,  -5],
              [-10,   5,  -2,  -5,   0,   3,  -3],
              [  7,  -3,  -2,   7,   1, -10,  -8],
              [  8,  -5,  -4,  -9,   8,   4,   9],
              [ -3,  -4,   6,  -3,  -2,   8,   3],
              [  4,  -8,  -5,  -6,   1,   5,   1]])

b = np.array([[ -2,  -1,   4, -10,  -1,   8,   5],
              [ -1,  -1,  -5,  -9,   0,   5,  -7],
              [ -5,  -5,  -2,  -6,   9,   8,  -6],
              [  2,   5,  -1,   4,  -8,  -2,   1],
              [ -6,  -5,   6,   1,   1,   5,  -7],
              [  0,   3,  -8,  -1,  -3,   9,   1],
              [  9,   7,  -7,   5,  -1,  -9,   6]])

# %%
2*a - 3*b
# Out:
# array([[ 12,  13, -22,  18, -15, -20, -19],
#        [-17,  -3,   5,  27,  12,   3,  11],
#        [ -5,  25,   2,   8, -27, -18,  12],
#        [  8, -21,  -1,   2,  26, -14, -19],
#        [ 34,   5, -26, -21,  13,  -7,  39],
#        [ -6, -17,  36,  -3,   5, -11,   3],
#        [-19, -37,  11, -27,   5,  37, -16]])

# %% [markdown]
# # Task_3
#
# Дана матрица, где колонки - это переменные $x$ и $y$ соответственно. Для каждой пары элементов массивов выполните вычисление по формуле:
#
# $$z = 2x + 3y - xy$$

# %%
arr = np.array([x, y]).T
arr
# Out:
# array([[-3, 13],
#        [-3,  0],
#        [12,  9],
#        [ 7, -1],
#        [ 2, 12],
#        [ 5,  4],
#        [-5,  1],
#        [-1,  1],
#        [ 3,  0],
#        [12, 13],
#        [ 3,  8],
#        [-4, 14],
#        [ 9, -3],
#        [14, -5],
#        [-1,  2],
#        [ 1,  8],
#        [ 4, -3],
#        [13,  2],
#        [ 9, 10],
#        [ 5, -3]])

# %%
z = 2*arr[:,0] + 3*arr[:,1] - arr[:,0]*arr[:,1]

# %%
z
# Out:
# array([ 72,  -6, -57,  18,  16,   2,  -2,   2,   6, -93,   6,  90,  36,
#         83,   6,  18,  11,   6, -42,  16])

# %% [markdown]
# # Task_4
#
# Дана матрица чисел. Вычислите
#
# * Сумму всех элементов
# * Сумму элементов каждой строки
# * Сумму элементов каждого столбца
# * Среднее по строкам
# * Медиану по столбцам
# * Минимальное значение из каждой строки
# * Сумму всех минимальных значений по каждой строке
# * Для каждого строкстолбца сумму квадратов элементов.

# %%
matr = np.array([[  5,   8,  -2,   7,  -6,  -2],
                [  8,  -2,  -1, -10, -10,   7],
                [  5,   9, -10,  -4,   1,   3],
                [  1,   2,  -7,   6,  -6,  -2],
                [  8,   4, -10,  -9,   1,  -6]])

# %%
matr.sum()
# Out:
# np.int64(-12)

# %%
matr.sum(1)
# Out:
# array([ 10,  -8,   4,  -6, -12])

# %%
matr.sum(0)
# Out:
# array([ 27,  21, -30, -10, -20,   0])

# %%
matr.mean(1)
# Out:
# array([ 1.66666667, -1.33333333,  0.66666667, -1.        , -2.        ])

# %% [markdown]
# # Task_5
#
# Дан одномерный массив. Сделайте его преобразование по формуле.
#
# $$X_{norm} = \frac{X - x_{min}}{x_{max} - x_{min}}$$

# %%
x = np.array([ 5, -7,  1, -5, -7, -5,  6, -1, -5, -9,  8,  1, -9, -6, -2])

# %%
(x - np.min(x)) / (np.max(x) - np.min(x))
# Out:
# array([0.82352941, 0.11764706, 0.58823529, 0.23529412, 0.11764706,
#        0.23529412, 0.88235294, 0.47058824, 0.23529412, 0.        ,
#        1.        , 0.58823529, 0.        , 0.17647059, 0.41176471])

# %% [markdown]
# # Task_6
#
# Дана числовая матрица. Преобразуйте каждый столбец по формуле:
#
# $$X_{norm} = \frac{X - x_{min}}{x_{max} - x_{min}}$$

# %%
matrix = np.array([[ -9,  -9,  -6,  -4,   2,   2,  -7],
                    [ -5,  -6,  -3,   6,   9,  -3,  -6],
                    [ -8,   2,   4,   1,  -1,  -8,   0],
                    [  0,   1,   5,  -3,   9,   1,   6],
                    [ -1,  -3,  -8,  -9,  -7,  -3, -10],
                    [ -8,   0, -10,  -9,   4, -10,   0],
                    [ -8, -10,  -9, -10,   5,   4,  -1]])

# %%
matrix.min(axis=0)[:, np.newaxis]    # .reshape(7,1)
# Out:
# array([[ -9],
#        [-10],
#        [-10],
#        [-10],
#        [ -7],
#        [-10],
#        [-10]])

# %%
matrix.min(axis=0)
# Out:
# array([ -9, -10, -10, -10,  -7, -10, -10])

# %%
(matrix - matrix.min(axis=0)) / (matrix.max(axis=0) - matrix.min(axis=0))
# Out:
# array([[0.        , 0.08333333, 0.26666667, 0.375     , 0.5625    ,
#         0.85714286, 0.1875    ],
#        [0.44444444, 0.33333333, 0.46666667, 1.        , 1.        ,
#         0.5       , 0.25      ],
#        [0.11111111, 1.        , 0.93333333, 0.6875    , 0.375     ,
#         0.14285714, 0.625     ],
#        [1.        , 0.91666667, 1.        , 0.4375    , 1.        ,
#         0.78571429, 1.        ],
#        [0.88888889, 0.58333333, 0.13333333, 0.0625    , 0.        ,
#         0.5       , 0.        ],
#        [0.11111111, 0.83333333, 0.        , 0.0625    , 0.6875    ,
#         0.        , 0.625     ],
#        [0.11111111, 0.        , 0.06666667, 0.        , 0.75      ,
#         1.        , 0.5625    ]])

# %%
(matrix - np.min(matrix)) / (np.max(matrix) - np.min(matrix))
# Out:
# array([[0.05263158, 0.05263158, 0.21052632, 0.31578947, 0.63157895,
#         0.63157895, 0.15789474],
#        [0.26315789, 0.21052632, 0.36842105, 0.84210526, 1.        ,
#         0.36842105, 0.21052632],
#        [0.10526316, 0.63157895, 0.73684211, 0.57894737, 0.47368421,
#         0.10526316, 0.52631579],
#        [0.52631579, 0.57894737, 0.78947368, 0.36842105, 1.        ,
#         0.57894737, 0.84210526],
#        [0.47368421, 0.36842105, 0.10526316, 0.05263158, 0.15789474,
#         0.36842105, 0.        ],
#        [0.10526316, 0.52631579, 0.        , 0.05263158, 0.73684211,
#         0.        , 0.52631579],
#        [0.10526316, 0.        , 0.05263158, 0.        , 0.78947368,
#         0.73684211, 0.47368421]])

# %% [markdown]
# # Task_6_B
#
# Дан многомерный массив с картинками. Нормализуйте каждую картинку.

# %%
images = np.random.randint(0, 255, (10, 3, 64, 64))
images.shape
# Out:
# (10, 3, 64, 64)

# %%
(images - np.min(images, axis = 0)) / np.max(images, axis = 0) - np.min(images, axis = 0)
# Out:
# array([[[[-6.40000000e+01, -8.28301887e+00,  1.00000000e+00, ...,
#           -4.24527363e+01, -3.06896552e+00, -1.36444444e+00],
#          [ 7.28571429e-01,  2.90456432e-01, -5.57142857e+00, ...,
#           -1.98227848e+01, -1.03966942e+01, -1.00000000e+00],
#          [-4.02202643e+00, -1.42387387e+01, -9.00000000e+00, ...,
#           -7.60000000e+01, -2.97029289e+01, -5.07923729e+01],
#          ...,
#          [-7.66122449e+00, -2.00000000e+01, -7.10144928e+00, ...,
#           -5.92479339e+01, -2.43640351e+01, -4.05421687e+01],
#          [-6.36250000e+01, -2.60000000e+01, -2.21836735e+01, ...,
#           -3.04897959e+01, -2.51238095e+01, -1.20000000e+01],
#          [-2.71327014e+01, -1.14928854e+02,  5.36000000e-01, ...,
#           -2.20000000e+01, -1.19827586e+01, -1.08296943e+01]],
#
#         [[-8.41025641e+00, -5.55555556e-03,  9.24000000e-01, ...,
#           -1.30877193e+01, -1.80000000e+01, -2.01209677e+00],
#          [-6.73399209e+01, -1.10483871e+01, -7.71559633e+00, ...,
#           -2.64023904e+01, -4.46504065e+01, -2.56839827e+01],
#          [-6.37681159e-01, -2.15113122e+01, -1.00000000e+00, ...,
#           -4.23125000e+01, -4.33662551e+01, -2.00000000e+00],
#          ...,
#          [-2.78524590e+01, -8.67068273e+01, -2.54203540e+01, ...,
#           -4.39444444e+01, -4.06825397e+01, -6.35920000e+01],
#          [-7.38000000e+00, -7.50413223e+00, -2.87665198e+01, ...,
#            7.67295597e-01, -4.73933054e+01, -6.89763780e+00],
#          [-6.59177489e+01, -1.16542056e+01,  1.90476190e-01, ...,
#           -9.56962025e+00,  6.48760331e-01, -6.08897638e+01]],
#
#         [[-6.32807018e+01, -1.64724771e+01, -6.88299595e+01, ...,
#           -1.36637168e+01, -4.83723849e+01, -5.84615385e+00],
#          [-1.83689840e+01, -2.48481013e+01, -3.67579909e+01, ...,
#           -2.92431193e+01, -1.89680851e+01, -5.38774704e+01],
#          [-2.16587678e+00, -2.11358025e+01, -1.61269841e+01, ...,
#           -3.85169492e+01, -7.55066079e+00, -9.69230769e+00],
#          ...,
#          [-7.50000000e-02, -1.43283582e+01, -1.72850000e+01, ...,
#           -2.50000000e+00, -3.77609562e+01, -5.19521912e+01],
#           -3.87711864e+01, -7.42731278e+00, -1.00000000e+01],
#          ...,
#          [-3.66666667e-01, -1.50000000e+01, -1.71800000e+01, ...,
#           -3.00000000e+00, -3.76613546e+01, -5.12071713e+01],
#          [-9.57520000e+01, -3.21968504e+01, -2.78414097e+00, ...,
#           -2.00000000e+00, -2.81160000e+01, -3.00000000e+00],
#          [-4.74800000e+00, -2.38897638e+01, -2.66956522e+01, ...,
#           -5.86561265e+01, -1.44758065e+01, -1.56180258e+01]]]])

# %% [markdown]
# # Task_7
#
# Дан двумерный набор чисел, где каждая строка - это стороны параллелепипеда. *(Для справки: аквариум, каждая грань которого - прямоугольник, является параллелепипедом)*
#
# Вычислите главную диагональ каждого параллелепипеда. Для этого существует "трехмерная" теорема Пифагора.
#
# $$d = \sqrt{a^2 + b^2 + c^2}$$

# %%
fig = np.array([[ 1, 12,  1],
                [ 1, 19, 19],
                [ 6, 10,  4],
                [13,  6, 15],
                [ 7,  2, 13],
                [18, 11, 16],
                [18, 13,  8],
                [ 5,  8, 19],
                [ 7, 13, 18],
                [ 4, 12, 14]])

# %%
np.sqrt((fig**2).sum(axis=1))
# Out:
# array([12.08304597, 26.88865932, 12.32882801, 20.73644135, 14.89966443,
#        26.47640459, 23.60084744, 21.21320344, 23.28089345, 18.86796226])

# %% [markdown]
# ## Task_8
#
# Даны два одномерных числовых массива. Для каждой пары рассчитайте среднее гармоническое.
#
# $$x_{garm} = \frac{n}{\frac{1}{x_1}+\frac{1}{x_2}+ ... + \frac{1}{x_n}}$$

# %%
x_1 = np.array([19,  1,  2,  6,  5,  2,  6,  1, 12, 19])
x_2 = np.array([ 1,  5,  1,  6, -9,  8, -3,  10,  4,  5])

# %%
2/(1/x_1 + 1/x_2)
# Out:
# array([  1.9       ,   1.66666667,   1.33333333,   6.        ,
#         22.5       ,   3.2       , -12.        ,   1.81818182,
#          6.        ,   7.91666667])

# %% [markdown]
# # Task_9
#
# Дана числовая матрица. Для каждого ее столбца вычислите среднее гармоническое.

# %%
matrix = np.array([[13,  1,  8, 18, 18,  1, 18, 15, 14, 18],
                    [12, 11, 17, 15, 15,  8,  4,  7, 16, 15],
                    [ 6, 17,  7,  5,  7,  1, 17, 12, 16, 19],
                    [14, 10, 12, 18,  6, 18,  5, 19, 19, 17],
                    [ 5, 14, 11,  5,  1, 16,  1,  7, 19, 19],
                    [13, 18, 14,  1,  5,  4,  4,  4, 17,  7],
                    [16,  9, 11, 14, 17,  1,  9, 18, 18,  4],
                    [16,  2, 17, 11, 13, 16,  8,  3, 15,  1],
                    [ 9,  6,  2,  7,  1,  9, 19,  7, 15,  4],
                    [13,  1, 10, 11, 16,  8,  4, 18,  6, 11]])

# %%
matrix.shape[0]/(1/matrix).sum(axis=0)
# Out:
# array([10.11829385,  3.17008   ,  7.56381427,  5.06615981,  3.5335781 ,
#         2.63736264,  4.24967382,  7.54348374, 13.96509926,  4.9503109 ])

# %% [markdown]
# # Task_10
#
# Для массива из предыдущей задачи верните одномерный массив, где каждый элемент показывает, на сколько среднее в колонке отклоняется от среднего по всему массиву в абсолютном значении. Вам понадобится модуль разности.

# %%
matrix.size/(1/matrix).sum().item()
# Out:
# 4.883922855602985

# %% [markdown]
# # Task_11
#
# Вы делаете анализ рынка недвижимости. Перед вами задача для каждого земельного участка вычислить стоимость одной сотки земли. Вам даны 2 массива с необходимыми значениями. В Данных есть ошибки и некорректные значения. После рассчета, произведите чистку полученного массива.

# %%
usd_price = np.array([ 96738., 135596.,  96282., 150607.,  67225.,  20191., 189050.,
                    149399.,  81149.,     np.nan, 123021., 117118.,  78244.,  61019.,
                        np.nan,     np.nan,     np.nan, 172613.,  96979., 145361., 179801.,
                    192873.,  17723.,  38203.,  18272.,  47141., 197610., 120982.,
                      29517.,     np.nan,  10968., 142459.,  87694.,  95156.,  11441.,
                      69183., 128058., 120072.,  71501., 172044., 155418.,  74643.,
                      22135., 169163.,  96552., 177093.,  13314.,  25725.,  20973.,
                      48835.])
squere = np.array([11, 10,  4, 19, 12, 17, 16, 16,  3, 11, 16, 0, 18, 13, 16,  4,  8,
                  10, 16, 19,  7, 16,  6, 11, 11, 18, 14, 11,  8,  3, 19,  5,  9,  8,
                  16,  5, 11,  3, 19,  4, 17, 0, 17, 12,  9,  4,  7, 14, 17, 0])

# %%
ps = usd_price/squere
# Out:
# /tmp/ipython-input-81-76653656.py:1: RuntimeWarning: divide by zero encountered in divide
#   ps = usd_price/squere

# %%
ps = ps[~(np.isnan(ps)) & ~(np.isinf(ps))]

# %% [markdown]
# # Task_12
#
# Дан числовой массив. Измените его таким образом, чтобы все нечетные элементы стали иметь значение 0. Используйте функцию `where()`.

# %%
arr = np.arange(1, 50).reshape(7, 7)

# %% [markdown]
# # Task_13
#
# Даны два одномерных числовых набора.
#
# * mean_price - средняя стоимость продуктов в категории.
# * price - реальная стоимость продукта в соответствующей категории.
#
# Отредактируйте массив price таким образом, чтобы в нем те значения стоимости, которые отклоняются от средней более чен на 30% были заменены на nan. Используйте функцию `where()`.

# %%
mean_price  = np.array([18013, 16619, 12592, 19584,  9968, 11577, 17709,  7279,  7187,
                        15799,  7496,  7944, 13496, 15644,  7147, 19940,  5733,  9576,
                        19029,  8327])
price = np.array([ 9006, 23267, 12592, 21542, 10965,  8104, 21251,  8007,  3594,
                  22119,  8246,  4766, 18894, 10951,  9291, 21934,  5160,  9576,
                  20932,  4164])

# %%
mean_price - price
# Out:
# array([ 9007, -6648,     0, -1958,  -997,  3473, -3542,  -728,  3593,
#        -6320,  -750,  3178, -5398,  4693, -2144, -1994,   573,     0,
#        -1903,  4163])

# %% [markdown]
# # Task_13
#
# Дана числовая матрица. Мы хотим каждый элемент каждой строки увеличить на сколько-то процентов. Для этого нам дан список со значением процентного числа для каждого столбца. Выполните коррекцию значений матрицы.

# %%
matrix = np.array([[41, 10, 23, 26, 38],
                  [42, 33, 44, 40, 36],
                  [27, 40, 38, 12, 37],
                  [25, 28, 47, 31, 37],
                  [25, 33, 43, 20, 38]])
perc_list = np.array([10, 15, 5, 25, 40])

# %%
matrix * (perc_list/100 + 1)
# Out:
# array([[45.1 , 11.5 , 24.15, 32.5 , 53.2 ],
#        [46.2 , 37.95, 46.2 , 50.  , 50.4 ],
#        [29.7 , 46.  , 39.9 , 15.  , 51.8 ],
#        [27.5 , 32.2 , 49.35, 38.75, 51.8 ],
#        [27.5 , 37.95, 45.15, 25.  , 53.2 ]])

# %% [markdown]
# # Task_14*
#
# Дан массив, где каждая строка - это координаты точки в декартовом двумерном пространстве. Все точки образуют Кластер. Найдите координату середины данного кластера.

# %%
coords = np.random.randn(100, 2) + np.array([2, 3])

# %%
# vizual
import seaborn as sns

# %%
centroids = coords.mean(axis=0)

# %%
sns.scatterplot(x = coords[:, 0], y = coords[:, 1], color='green')
sns.scatterplot(x = [centroids[0]], y = [centroids[1]], color='red')
# Out:
# <Axes: >

# %% [markdown]
# # Task_15*
#
# Решив предыдущую задачу, вычислите все расстояния от каждой точки до центроида. Результат представьте в виде одномерного массива.
#
# $$\rho(m_i, m_{centr}) = \sqrt{(x_{m_i} - x_{m_{centr}})^2 + ((y_{m_i} - y_{m_{centr}})^2}$$

# %%
# First way (w/o using axis)
distance = np.sqrt((coords[:, 0] - centroids[0])**2  + (coords[:, 1] - centroids[1])**2)
distance
# Out:
# array([1.03945675, 0.6646276 , 1.95575359, 1.16923314, 0.86541229,
#        0.40664598, 0.88447403, 0.80545747, 2.90757323, 0.59570802,
#        1.1171956 , 1.09377367, 0.86624583, 0.75508226, 2.74350317,
#        1.56214365, 1.08976065, 0.69276165, 2.11525083, 0.84350038,
#        1.47928578, 0.37533563, 1.15792793, 1.12196159, 1.0223309 ,
#        0.8712402 , 2.4425178 , 0.89081363, 1.47607286, 0.89621069,
#        0.30050455, 0.78475148, 0.83621666, 0.9767354 , 1.20132255,
#        2.58798045, 1.60666974, 0.96970674, 1.27021846, 1.02706502,
#        1.03664654, 1.15350702, 0.52620014, 1.63658453, 0.66217903,
#        1.45130648, 1.97326133, 0.78684661, 2.46847607, 1.25791907,
#        1.75231333, 0.61581498, 1.09147723, 1.94251035, 0.55713878,
#        0.97786201, 1.29742426, 1.42814644, 0.13806599, 1.32565127,
#        0.67213464, 1.10885896, 0.3523687 , 2.04864624, 0.95493587,
#        0.66057537, 1.5784857 , 0.9733958 , 3.50766647, 0.90275518,
#        1.54701871, 2.564065  , 0.62102919, 1.23404779, 1.27319348,
#        1.2299498 , 1.77973334, 1.00249752, 2.24577059, 1.00375755,
#        1.21270794, 0.49326467, 1.48554605, 1.01136972, 2.47805781,
#        2.69488126, 0.44888829, 1.9703054 , 0.75506304, 2.32886948,
#        1.60558309, 1.026946  , 1.46828287, 0.38568087, 0.65245185,
#        1.12709662, 1.27260178, 2.80780359, 1.16895385, 0.90934457])

# %%
# Second way (using axis)
distance = np.sqrt(((coords - centroids)**2).sum(axis=1))
distance
# Out:
# array([1.03945675, 0.6646276 , 1.95575359, 1.16923314, 0.86541229,
#        0.40664598, 0.88447403, 0.80545747, 2.90757323, 0.59570802,
#        1.1171956 , 1.09377367, 0.86624583, 0.75508226, 2.74350317,
#        1.56214365, 1.08976065, 0.69276165, 2.11525083, 0.84350038,
#        1.47928578, 0.37533563, 1.15792793, 1.12196159, 1.0223309 ,
#        0.8712402 , 2.4425178 , 0.89081363, 1.47607286, 0.89621069,
#        0.30050455, 0.78475148, 0.83621666, 0.9767354 , 1.20132255,
#        2.58798045, 1.60666974, 0.96970674, 1.27021846, 1.02706502,
#        1.03664654, 1.15350702, 0.52620014, 1.63658453, 0.66217903,
#        1.45130648, 1.97326133, 0.78684661, 2.46847607, 1.25791907,
#        1.75231333, 0.61581498, 1.09147723, 1.94251035, 0.55713878,
#        0.97786201, 1.29742426, 1.42814644, 0.13806599, 1.32565127,
#        0.67213464, 1.10885896, 0.3523687 , 2.04864624, 0.95493587,
#        0.66057537, 1.5784857 , 0.9733958 , 3.50766647, 0.90275518,
#        1.54701871, 2.564065  , 0.62102919, 1.23404779, 1.27319348,
#        1.2299498 , 1.77973334, 1.00249752, 2.24577059, 1.00375755,
#        1.21270794, 0.49326467, 1.48554605, 1.01136972, 2.47805781,
#        2.69488126, 0.44888829, 1.9703054 , 0.75506304, 2.32886948,
#        1.60558309, 1.026946  , 1.46828287, 0.38568087, 0.65245185,
#        1.12709662, 1.27260178, 2.80780359, 1.16895385, 0.90934457])

# %%
sns.scatterplot(x = coords[:, 0], y = coords[:, 1], hue = distance)
sns.scatterplot(x = [centroids[0]], y = [centroids[1]], color='red')
# Out:
# <Axes: >

# %% [markdown]
# # Clustering_Task***

# %% [markdown]
# Даны два гаусова кластера - два облака точек, распределенных вокруг заданных центроидов в двумерном пространстве. Кластеры будем называть 1 и -1.
#
# `centroids` - массив, где две строки - это координаты $x$ и $y$ центроидов 1 и -1.
#
# Каждой точке, которая задана координатами в массиве coords, постаьте в соответствие метку кластера 1 или -1 в зависимости от того, к какомы центроиду эта точка ближе. Вы получите одномерный массив с количеством элементов равному количеству точек.

# %%
centroids = np.array([[5, 2], [2, 4]])
coords = np.concatenate([np.random.randn(120, 2)+centroids[0], np.random.randn(145, 2)+centroids[1]], axis=0)
coords[:5]
# Out:
# array([[5.62363393, 2.44992436],
#        [5.28113073, 4.23067204],
#        [3.83904434, 2.21795804],
#        [6.12089696, 2.94729502],
#        [4.10585218, 2.56295518]])

# %%
distance1 = np.sqrt(((coords - centroids[0])**2).sum(axis=1))
distance2 = np.sqrt(((coords - centroids[1])**2).sum(axis=1))
clastering = np.where(distance1 > distance2, 1, -1)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Разделим по кластерам
cluster_0 = coords[clastering == -1]
cluster_1 = coords[clastering == 1]

# Рисуем
plt.figure(figsize=(8, 6))
plt.scatter(cluster_0[:, 0], cluster_0[:, 1], c='blue', label='Cluster 0 (-1)', alpha=0.6)
plt.scatter(cluster_1[:, 0], cluster_1[:, 1], c='orange', label='Cluster 1 (+1)', alpha=0.6)

# Нарисуем центры
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

# Красота
plt.title("Кластеризация точек по расстоянию")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()

# %%
sns.scatterplot(x = coords[:, 0], y = coords[:, 1], color='green')
sns.scatterplot(x = centroids[:, 0], y = centroids[:, 1], color='red')
# Out:
# <Axes: >

# %%
claster1 = np.random.randn(140, 2)+centroids[0]
claster2 = np.random.randn(160, 2)+centroids[1]

# %%
sns.scatterplot(x = coords[:, 0], y = coords[:, 1], color='orange')
sns.scatterplot(x = claster1[:, 0], y = claster1[:, 1], color='green')
sns.scatterplot(x = claster2[:, 0], y = claster2[:, 1], color='blue')
sns.scatterplot(x = centroids[:, 0], y = centroids[:, 1], color='red')
# Out:
# <Axes: >
